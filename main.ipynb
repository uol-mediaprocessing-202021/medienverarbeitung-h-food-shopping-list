# %% [markdown]
# <a href="https://colab.research.google.com/github/uol-mediaprocessing-202021/medienverarbeitung-h-food-shopping-list/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision import transforms
from PIL import Image
import cv2
import matplotlib.pyplot as plt

normalize = transforms.Normalize(
    mean=[0.485, 0.456, 4.406],
    std=[0.229, 0.224, 0.225]
)

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(256),
    transforms.ToTensor(),
    normalize                             
])

img = Image.open("/content/Products/Margarine/Laetta/IMG_20201119_162047.jpg")

img_tensor = transform(img)
img_tensor.unsqueeze_(0)
print(img_tensor)

img = cv2.imread("/content/Products/Margarine/Laetta/IMG_20201119_162047.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
# Out:
# tensor([[[[-1.0048e+00, -9.8767e-01, -9.8767e-01,  ..., -6.2934e-02,
#            -8.0058e-02, -8.0058e-02],
#           [-9.8767e-01, -9.7055e-01, -9.5342e-01,  ..., -2.8684e-02,
#            -4.5809e-02, -4.5809e-02],
#           [-9.5342e-01, -9.3630e-01, -9.1917e-01,  ...,  5.5655e-03,
#             5.5655e-03, -1.1559e-02],
#           ...,
#           [ 7.9330e-01,  8.2755e-01,  7.9330e-01,  ...,  7.4193e-01,
#             7.5905e-01,  7.9330e-01],
#           [ 7.5905e-01,  7.9330e-01,  8.1043e-01,  ...,  7.4193e-01,
#             7.4193e-01,  7.5905e-01],
#           [ 7.5905e-01,  7.7618e-01,  8.1043e-01,  ...,  7.2481e-01,
#             7.0768e-01,  7.2481e-01]],
#
#          [[-1.4405e+00, -1.4230e+00, -1.4230e+00,  ..., -4.2507e-01,
#            -4.4258e-01, -4.4258e-01],
#           [-1.4230e+00, -1.4055e+00, -1.4055e+00,  ..., -3.9006e-01,
#            -4.2507e-01, -4.0756e-01],
#           [-1.3880e+00, -1.3880e+00, -1.3880e+00,  ..., -3.5504e-01,
# ...
